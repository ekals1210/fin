# %% [markdown]
# # REST API
# - HTTP URI를 통해 자원을 명시하고, HTTP Method (POST, GET, PUT, DELETE)를 통해 해당 자원에 대한 CRUD OPERATION을 적용하는 것을 의미한다.
# - 즉, REST는 자원 기반의 구조 (ROA: Resource Oriented Architecture) 설계의 중심에 Resoure가 있고 HTTP Method를 통해 Resource를 처리하도록 설계된 아키텍쳐를 의미한다.
# - 웹의 모든 자원에 고유한 ID인 HTTP URI 를 부여한다.
#
# <img src="https://velog.velcdn.com/images/somday/post/2a7df2da-2a3c-44af-b059-ee03efc125ef/restapi-image.png">
#
# - https://velog.io/@somday/RESTful-API-%EC%9D%B4%EB%9E%80

# %%
# xml을 dict 형태로 저장하는 라이브러리 설치
# !pip install xmltodict
# Out:
# Collecting xmltodict
#   Downloading xmltodict-0.13.0-py2.py3-none-any.whl.metadata (7.7 kB)
# Downloading xmltodict-0.13.0-py2.py3-none-any.whl (10.0 kB)
# Installing collected packages: xmltodict
# Successfully installed xmltodict-0.13.0

# %%
# 필수 라이브러리 불러오기
import requests
import json
import xmltodict
import getpass

# %%
# 영화진흥위원회 오픈API 정보 저장
# https://www.kobis.or.kr/kobisopenapi/homepg/apiservice/searchServiceInfo.do

# %%
api_key = "00056c423cbaf7d6288c251e09464722"
search_url = "http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieList.json"

params = {"key" : api_key,
         "curPage" : 1}

# %%
response = requests.get(search_url, params)

# %%
movie_info = json.loads(response.text)

# %%
movie_info["movieListResult"]["movieList"]
# Out:
# [{'movieCd': '20240788',
#   'movieNm': '13회 광주독립영화제 - 메이드 인 광주 : NEXT10',
#   'movieNmEn': '',
#   'prdtYear': '2024',
#   'openDt': '',
#   'typeNm': '옴니버스',
#   'prdtStatNm': '기타',
#   'nationAlt': '한국',
#   'genreAlt': '드라마',
#   'repNationNm': '한국',
#   'repGenreNm': '드라마',
#   'directors': [],
#   'companys': []},
#  {'movieCd': '20240787',
#   'movieNm': '13회 광주독립영화제 - 5월 이야기',
#   'movieNmEn': '',
#   'prdtYear': '2024',
#   'openDt': '',
#   'typeNm': '옴니버스',
#   'prdtStatNm': '기타',
#   'nationAlt': '한국',
#   'genreAlt': '드라마,다큐멘터리',
#   'repNationNm': '한국',
#   'repGenreNm': '드라마',
#   'directors': [],
#   'companys': []},
#  {'movieCd': '20240786',
#   'movieNm': '13회 광주독립영화제 - 메이드 인 광주 1',
#   'movieNmEn': '',
#   'prdtYear': '2024',
#   'openDt': '',
#   'typeNm': '옴니버스',
#   'prdtStatNm': '기타',
#   'nationAlt': '한국',
#   'genreAlt': '드라마',
#   'repNationNm': '한국',
#   'repGenreNm': '드라마',
#   'directors': [],
#   'companys': []},
#  {'movieCd': '20248574',
#   'movieNm': '내 이름',
#   'movieNmEn': 'My name',
#   'prdtYear': '2024',
#   'openDt': '',
#   'typeNm': '장편',
#   'prdtStatNm': '기타',
#   'nationAlt': '한국',
#   'genreAlt': '드라마',
#   'repNationNm': '한국',
#   'repGenreNm': '드라마',
#   'directors': [{'peopleNm': '송원재'}],
#   'companys': []},
#  {'movieCd': '20240781',
#   'movieNm': '플라이 미 투 더 문',
#   'movieNmEn': 'Fly Me to the Moon',
#   'prdtYear': '2024',
#   'openDt': '',
#   'typeNm': '장편',
#   'prdtStatNm': '개봉예정',
#   'nationAlt': '미국,영국',
#   'genreAlt': '멜로/로맨스,코미디',
#   'repNationNm': '미국',
#   'repGenreNm': '멜로/로맨스',
#   'directors': [{'peopleNm': '그랙 버랜티'}],
#   'companys': []},
#  {'movieCd': '20225823',
#   'movieNm': '카브리올레',
#   'movieNmEn': 'Cabriolet',
#   'prdtYear': '2021',
#   'openDt': '',
#   'typeNm': '장편',
#   'prdtStatNm': '개봉예정',
#   'nationAlt': '한국',
#   'genreAlt': '드라마',
#   'repNationNm': '한국',
#   'repGenreNm': '드라마',
#   'directors': [{'peopleNm': '조광진'}],
#   'companys': []},
#  {'movieCd': '20240441',
#   'movieNm': '노 웨이 업',
#   'movieNmEn': 'No Way Up',
#   'prdtYear': '2024',
#   'openDt': '',
#   'typeNm': '장편',
#   'prdtStatNm': '개봉예정',
#   'nationAlt': '영국',
#   'genreAlt': '액션,스릴러',
#   'repNationNm': '영국',
#   'repGenreNm': '액션',
#   'directors': [{'peopleNm': '클라우디오 파'}],
#   'companys': []},
#  {'movieCd': '20249845',
#   'movieNm': '결속밴드 라이브 -항성-',
#   'movieNmEn': '',
#   'prdtYear': '2023',
#   'openDt': '20240529',
#   'typeNm': '장편',
#   'prdtStatNm': '개봉예정',
#   'nationAlt': '일본',
#   'genreAlt': '공연',
#   'repNationNm': '일본',
#   'repGenreNm': '공연',
#   'directors': [],
#   'companys': []},
#  {'movieCd': '20249733',
#   'movieNm': '사랑의 하츄핑',
#   'movieNmEn': '',
#   'prdtYear': '2024',
#   'openDt': '',
#   'typeNm': '장편',
#   'prdtStatNm': '개봉예정',
#   'nationAlt': '한국',
#   'genreAlt': '애니메이션',
#   'repNationNm': '한국',
#   'repGenreNm': '애니메이션',
#   'directors': [{'peopleNm': '김수훈'}],
#   'companys': [{'companyCd': '20000384', 'companyNm': '(주)에스에이엠지엔터테인먼트'}]},
#  {'movieCd': '20240739',
#   'movieNm': '넣어준 가정교사 무삭제판',
#   'movieNmEn': '',
#   'prdtYear': '2023',
#   'openDt': '',
#   'typeNm': '장편',
#   'prdtStatNm': '기타',
#   'nationAlt': '일본',
#   'genreAlt': '멜로/로맨스',
#   'repNationNm': '일본',
#   'repGenreNm': '멜로/로맨스',
#   'directors': [{'peopleNm': '사루'}],
#   'companys': []}]

# %%
# 영화 제목으로 영화 코드를 불러오는 함수를 만들어 보자
# 인어공주를 검색해서 출력할 수 있도록 만들어 보세요 


def movie_search(movie_name):
    api_key = "00056c423cbaf7d6288c251e09464722"
    search_url = "http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieList.json"
    params = {"key" : api_key,
             "movieNm" : movie_name}
    response = requests.get(search_url, params)
    movie_info = json.loads(response.text)
    return movie_info

movie_search("인어공주")
# Out:
# {'movieListResult': {'totCnt': 15,
#   'source': '영화진흥위원회',
#   'movieList': [{'movieCd': '20235562',
#     'movieNm': '인어공주: 마법물약의 비밀',
#     'movieNmEn': 'The Little Mermaid',
#     'prdtYear': '2023',
#     'openDt': '20240314',
#     'typeNm': '장편',
#     'prdtStatNm': '개봉',
#     'nationAlt': '미국',
#     'genreAlt': '애니메이션',
#     'repNationNm': '미국',
#     'repGenreNm': '애니메이션',
#     'directors': [],
#     'companys': []},
#    {'movieCd': '20231839',
#     'movieNm': '인어공주',
#     'movieNmEn': 'The Little Mermaid',
#     'prdtYear': '2023',
#     'openDt': '20230524',
#     'typeNm': '장편',
#     'prdtStatNm': '개봉',
#     'nationAlt': '미국',
#     'genreAlt': '뮤지컬,가족,판타지,멜로/로맨스',
#     'repNationNm': '미국',
#     'repGenreNm': '뮤지컬',
#     'directors': [{'peopleNm': '롭 마샬'}],
#     'companys': []},
#    {'movieCd': '20040515',
#     'movieNm': '인어 공주',
#     'movieNmEn': 'My Mother, The Mermaid',
#     'prdtYear': '2004',
#     'openDt': '20040630',
#     'typeNm': '장편',
#     'prdtStatNm': '개봉',
#     'nationAlt': '한국',
#     'genreAlt': '드라마',
#     'repNationNm': '한국',
#     'repGenreNm': '드라마',
#     'directors': [{'peopleNm': '박흥식'}],
#     'companys': [{'companyCd': '20100248', 'companyNm': '나우필름(주)'}]},
#    {'movieCd': '20201961',
#     'movieNm': '인어공주: 매직어드벤처',
#     'movieNmEn': 'The Little Mermaid',
#     'prdtYear': '2018',
#     'openDt': '',
#     'typeNm': '장편',
#     'prdtStatNm': '기타',
#     'nationAlt': '미국',
#     'genreAlt': '판타지',
#     'repNationNm': '미국',
#     'repGenreNm': '판타지',
#     'directors': [],
#     'companys': []},
#    {'movieCd': '20175603',
#     'movieNm': '인어공주 이야기 ',
#     'movieNmEn': "A Mermaid's Tale",
#     'prdtYear': '2016',
#     'openDt': '20171103',
#     'typeNm': '장편',
#     'prdtStatNm': '개봉',
#     'nationAlt': '미국',
#     'genreAlt': '판타지,드라마',
#     'repNationNm': '미국',
#     'repGenreNm': '판타지',
#     'directors': [],
#     'companys': []},
#    {'movieCd': '19970306',
#     'movieNm': '인어공주 ',
#     'movieNmEn': 'The Little Mermaid',
#     'prdtYear': '1989',
#     'openDt': '19911221',
#     'typeNm': '장편',
#     'prdtStatNm': '개봉',
#     'nationAlt': '미국',
#     'genreAlt': '애니메이션,멜로/로맨스,가족,뮤지컬',
#     'repNationNm': '미국',
#     'repGenreNm': '애니메이션',
#     'directors': [{'peopleNm': '존 머스커'}, {'peopleNm': '론 클레멘츠'}],
#     'companys': [{'companyCd': '20061393', 'companyNm': '월트디즈니'}]},
#    {'movieCd': '20144257',
#     'movieNm': '안녕 자두야 스페셜 : 인어공주 ',
#     'movieNmEn': '',
#     'prdtYear': '2013',
#     'openDt': '',
#     'typeNm': '단편',
#     'prdtStatNm': '기타',
#     'nationAlt': '한국',
#     'genreAlt': '애니메이션,코미디',
#     'repNationNm': '한국',
#     'repGenreNm': '애니메이션',
#     'directors': [{'peopleNm': '손석우'}],
#     'companys': []},
#    {'movieCd': '20162609',
#     'movieNm': '인어공주 : 새로운 모험의 시작',
#     'movieNmEn': 'The Little Mermaid : Attack of The Pirates',
#     'prdtYear': '2015',
#     'openDt': '20161103',
#     'typeNm': '장편',
#     'prdtStatNm': '개봉',
#     'nationAlt': '중국',
#     'genreAlt': '애니메이션',
#     'repNationNm': '중국',
#     'repGenreNm': '애니메이션',
#     'directors': [{'peopleNm': '아담 추'}],
#     'companys': []},
#    {'movieCd': '20156222',
#     'movieNm': '농염한 인어공주',
#     'movieNmEn': 'Erokichi sanpei zenra ningyodensetsu no nazo',
#     'prdtYear': '2003',
#     'openDt': '20151007',
#     'typeNm': '장편',
#     'prdtStatNm': '개봉',
#     'nationAlt': '일본',
#     'genreAlt': '멜로/로맨스,드라마',
#     'repNationNm': '일본',
#     'repGenreNm': '멜로/로맨스',
#     'directors': [{'peopleNm': '쿠로사바 아키라'}],
#     'companys': []},
#    {'movieCd': '20008033',
#     'movieNm': '인어공주 2',
#     'movieNmEn': 'The Little Mermaid II: Return To The Sea',
#     'prdtYear': '2000',
#     'openDt': '',
#     'typeNm': '장편',
#     'prdtStatNm': '기타',
#     'nationAlt': '미국,캐나다,호주',
#     'genreAlt': '애니메이션,가족',
#     'repNationNm': '미국',
#     'repGenreNm': '애니메이션',
#     'directors': [{'peopleNm': '짐 카메루드'}, {'peopleNm': '브라이언 스미스'}],
#     'companys': []}]}}

# %%
# 전날 박스오피스 확인 
d_boxoffice_url = "http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json"
params = {"key" : api_key,
         "targetDt" : "20240528"}
response = requests.get(d_boxoffice_url, params)
movie_box_office = json.loads(response.text)

# %%
from pandas import json_normalize

# %%
json_normalize(movie_box_office["boxOfficeResult"]["dailyBoxOfficeList"])
# Out:
#   rnum rank rankInten rankOldAndNew  ... audiChange   audiAcc scrnCnt showCnt
# 0    1    1         0           OLD  ...      -14.3    655277    1348    4490
# 1    2    2         0           OLD  ...      -15.8  11100967     916    3137
# 2    3    3         0           OLD  ...       -9.5    759322     879    2694
# 3    4    4         1           OLD  ...        2.3     86217     549    1216
# 4    5    5        -1           OLD  ...       -6.1    514695     565     917
# 5    6    6         0           OLD  ...       -0.6    879762     555     936
# 6    7    7         0           OLD  ...       31.5    255851     206     242
# 7    8    8         0           NEW  ...        100      1363       5       5
# 8    9    9         0           OLD  ...        5.4     90838      87     108
# 9   10   10        -2           OLD  ...      -10.4    100788     146     157
#
# [10 rows x 18 columns]

# %% [markdown]
# # 네이버API 를 이용해 Papago 번역서비스 사용하기

# %%
# 네이버 로그인 개발자 페이지 -> 키발급 -> papapgo 서비스
# https://developers.naver.com/docs/papago/papago-nmt-example-code.md#python
# https://developers.naver.com/

# %%
import os
import sys
import urllib.request
client_id = "LDsQbbqXv9YZRWYe1ZCL" # 개발자센터에서 발급받은 Client ID 값
client_secret = "TAn6RE2_aH" # 개발자센터에서 발급받은 Client Secret 값


url = "https://openapi.naver.com/v1/datalab/search"
body = "{\"startDate\":\"2024-01-01\",\"endDate\":\"2024-05-29\",\"timeUnit\":\"date\",\"keywordGroups\":[{\"groupName\":\"엔비디아\",\"keywords\":[\"엔비디아\",\"NVIDIA\",\"GeForce\"]}],\"device\":\"pc\",\"ages\":[\"1\",\"2\"],\"gender\":\"f\"}";

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
request.add_header("Content-Type","application/json")
response = urllib.request.urlopen(request, data=body.encode("utf-8"))
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {"startDate":"2024-01-01","endDate":"2024-05-29","timeUnit":"date","results":[{"title":"엔비디아","keywords":["엔비디아","NVIDIA","GeForce"],"data":[{"period":"2024-01-01","ratio":6.45161},{"period":"2024-01-02","ratio":16.12903},{"period":"2024-01-03","ratio":19.35483},{"period":"2024-01-04","ratio":3.2258},{"period":"2024-01-05","ratio":6.45161},{"period":"2024-01-06","ratio":12.90322},{"period":"2024-01-07","ratio":12.90322},{"period":"2024-01-08","ratio":6.45161},{"period":"2024-01-09","ratio":12.90322},{"period":"2024-01-10","ratio":12.90322},{"period":"2024-01-11","ratio":12.90322},{"period":"2024-01-12","ratio":9.67741},{"period":"2024-01-13","ratio":6.45161},{"period":"2024-01-14","ratio":3.2258},{"period":"2024-01-15","ratio":3.2258},{"period":"2024-01-16","ratio":12.90322},{"period":"2024-01-17","ratio":16.12903},{"period":"2024-01-18","ratio":16.12903},{"period":"2024-01-19","ratio":3.2258},{"period":"2024-01-20","ratio":12.90322},{"period":"2024-01-21","ratio":9.67741},{"period":"2024-01-22","ratio":16.12903},{"period":"2024-01-23","ratio":6.45161},{"period":"2024-01-24","ratio":9.67741},{"period":"2024-01-25","ratio":9.67741},{"period":"2024-01-26","ratio":6.45161},{"period":"2024-01-27","ratio":16.12903},{"period":"2024-01-29","ratio":25.80645},{"period":"2024-01-30","ratio":25.80645},{"period":"2024-01-31","ratio":3.2258},{"period":"2024-02-01","ratio":3.2258},{"period":"2024-02-02","ratio":9.67741},{"period":"2024-02-03","ratio":16.12903},{"period":"2024-02-04","ratio":6.45161},{"period":"2024-02-05","ratio":9.67741},{"period":"2024-02-06","ratio":9.67741},{"period":"2024-02-07","ratio":12.90322},{"period":"2024-02-08","ratio":6.45161},{"period":"2024-02-09","ratio":22.58064},{"period":"2024-02-10","ratio":12.90322},{"period":"2024-02-11","ratio":6.45161},{"period":"2024-02-12","ratio":9.67741},{"period":"2024-02-13","ratio":19.35483},{"period":"2024-02-14","ratio":3.2258},{"period":"2024-02-15","ratio":35.48387},{"period":"2024-02-16","ratio":9.67741},{"period":"2024-02-17","ratio":16.12903},{"period":"2024-02-18","ratio":16.12903},{"period":"2024-02-19","ratio":9.67741},{"period":"2024-02-20","ratio":6.45161},{"period":"2024-02-21","ratio":22.58064},{"period":"2024-02-22","ratio":9.67741},{"period":"2024-02-23","ratio":32.25806},{"period":"2024-02-24","ratio":25.80645},{"period":"2024-02-25","ratio":12.90322},{"period":"2024-02-26","ratio":22.58064},{"period":"2024-02-27","ratio":22.58064},{"period":"2024-02-28","ratio":12.90322},{"period":"2024-02-29","ratio":12.90322},{"period":"2024-03-01","ratio":9.67741},{"period":"2024-03-02","ratio":19.35483},{"period":"2024-03-03","ratio":19.35483},{"period":"2024-03-04","ratio":12.90322},{"period":"2024-03-05","ratio":19.35483},{"period":"2024-03-06","ratio":35.48387},{"period":"2024-03-07","ratio":29.03225},{"period":"2024-03-08","ratio":12.90322},{"period":"2024-03-09","ratio":25.80645},{"period":"2024-03-10","ratio":19.35483},{"period":"2024-03-11","ratio":32.25806},{"period":"2024-03-12","ratio":29.03225},{"period":"2024-03-13","ratio":51.6129},{"period":"2024-03-14","ratio":38.70967},{"period":"2024-03-15","ratio":9.67741},{"period":"2024-03-16","ratio":32.25806},{"period":"2024-03-17","ratio":16.12903},{"period":"2024-03-18","ratio":22.58064},{"period":"2024-03-19","ratio":32.25806},{"period":"2024-03-20","ratio":19.35483},{"period":"2024-03-21","ratio":80.64516},{"period":"2024-03-22","ratio":38.70967},{"period":"2024-03-23","ratio":16.12903},{"period":"2024-03-24","ratio":19.35483},{"period":"2024-03-25","ratio":25.80645},{"period":"2024-03-26","ratio":35.48387},{"period":"2024-03-27","ratio":35.48387},{"period":"2024-03-28","ratio":9.67741},{"period":"2024-03-29","ratio":12.90322},{"period":"2024-03-30","ratio":9.67741},{"period":"2024-03-31","ratio":29.03225},{"period":"2024-04-01","ratio":25.80645},{"period":"2024-04-02","ratio":16.12903},{"period":"2024-04-03","ratio":12.90322},{"period":"2024-04-04","ratio":35.48387},{"period":"2024-04-05","ratio":22.58064},{"pe ...

# %%
json.loads(response_body)
# Out:
# {'startDate': '2024-01-01',
#  'endDate': '2024-05-29',
#  'timeUnit': 'date',
#  'results': [{'title': '엔비디아',
#    'keywords': ['엔비디아', 'NVIDIA', 'GeForce'],
#    'data': [{'period': '2024-01-01', 'ratio': 6.45161},
#     {'period': '2024-01-02', 'ratio': 16.12903},
#     {'period': '2024-01-03', 'ratio': 19.35483},
#     {'period': '2024-01-04', 'ratio': 3.2258},
#     {'period': '2024-01-05', 'ratio': 6.45161},
#     {'period': '2024-01-06', 'ratio': 12.90322},
#     {'period': '2024-01-07', 'ratio': 12.90322},
#     {'period': '2024-01-08', 'ratio': 6.45161},
#     {'period': '2024-01-09', 'ratio': 12.90322},
#     {'period': '2024-01-10', 'ratio': 12.90322},
#     {'period': '2024-01-11', 'ratio': 12.90322},
#     {'period': '2024-01-12', 'ratio': 9.67741},
#     {'period': '2024-01-13', 'ratio': 6.45161},
#     {'period': '2024-01-14', 'ratio': 3.2258},
#     {'period': '2024-01-15', 'ratio': 3.2258},
#     {'period': '2024-01-16', 'ratio': 12.90322},
#     {'period': '2024-01-17', 'ratio': 16.12903},
#     {'period': '2024-01-18', 'ratio': 16.12903},
#     {'period': '2024-01-19', 'ratio': 3.2258},
#     {'period': '2024-01-20', 'ratio': 12.90322},
#     {'period': '2024-01-21', 'ratio': 9.67741},
#     {'period': '2024-01-22', 'ratio': 16.12903},
#     {'period': '2024-01-23', 'ratio': 6.45161},
#     {'period': '2024-01-24', 'ratio': 9.67741},
#     {'period': '2024-01-25', 'ratio': 9.67741},
#     {'period': '2024-01-26', 'ratio': 6.45161},
#     {'period': '2024-01-27', 'ratio': 16.12903},
#     {'period': '2024-01-29', 'ratio': 25.80645},
#     {'period': '2024-01-30', 'ratio': 25.80645},
#     {'period': '2024-01-31', 'ratio': 3.2258},
#     {'period': '2024-02-01', 'ratio': 3.2258},
#     {'period': '2024-02-02', 'ratio': 9.67741},
#     {'period': '2024-02-03', 'ratio': 16.12903},
#     {'period': '2024-02-04', 'ratio': 6.45161},
#     {'period': '2024-02-05', 'ratio': 9.67741},
#     {'period': '2024-02-06', 'ratio': 9.67741},
#     {'period': '2024-02-07', 'ratio': 12.90322},
#     {'period': '2024-02-08', 'ratio': 6.45161},
#     {'period': '2024-02-09', 'ratio': 22.58064},
#     {'period': '2024-02-10', 'ratio': 12.90322},
#     {'period': '2024-02-11', 'ratio': 6.45161},
#     {'period': '2024-02-12', 'ratio': 9.67741},
#     {'period': '2024-02-13', 'ratio': 19.35483},
#     {'period': '2024-02-14', 'ratio': 3.2258},
#     {'period': '2024-02-15', 'ratio': 35.48387},
#     {'period': '2024-02-16', 'ratio': 9.67741},
#     {'period': '2024-02-17', 'ratio': 16.12903},
#     {'period': '2024-02-18', 'ratio': 16.12903},
#     {'period': '2024-02-19', 'ratio': 9.67741},
#     {'period': '2024-02-20', 'ratio': 6.45161},
#     {'period': '2024-02-21', 'ratio': 22.58064},
#     {'period': '2024-02-22', 'ratio': 9.67741},
#     {'period': '2024-02-23', 'ratio': 32.25806},
#     {'period': '2024-02-24', 'ratio': 25.80645},
#     {'period': '2024-02-25', 'ratio': 12.90322},
#     {'period': '2024-02-26', 'ratio': 22.58064},
#     {'period': '2024-02-27', 'ratio': 22.58064},
#     {'period': '2024-02-28', 'ratio': 12.90322},
#     {'period': '2024-02-29', 'ratio': 12.90322},
#     {'period': '2024-03-01', 'ratio': 9.67741},
#     {'period': '2024-03-02', 'ratio': 19.35483},
#     {'period': '2024-03-03', 'ratio': 19.35483},
#     {'period': '2024-03-04', 'ratio': 12.90322},
#     {'period': '2024-03-05', 'ratio': 19.35483},
#     {'period': '2024-03-06', 'ratio': 35.48387},
#     {'period': '2024-03-07', 'ratio': 29.03225},
#     {'period': '2024-03-08', 'ratio': 12.90322},
#     {'period': '2024-03-09', 'ratio': 25.80645},
#     {'period': '2024-03-10', 'ratio': 19.35483},
#     {'period': '2024-03-11', 'ratio': 32.25806},
#     {'period': '2024-03-12', 'ratio': 29.03225},
#     {'period': '2024-03-13', 'ratio': 51.6129},
#     {'period': '2024-03-14', 'ratio': 38.70967},
#     {'period': '2024-03-15', 'ratio': 9.67741},
#     {'period': '2024-03-16', 'ratio': 32.25806},
#     {'period': '2024-03-17', 'ratio': 16.12903},
#     {'period': '2024-03-18', 'ratio': 22.58064},
#     {'period': '2024-03-19', 'ratio': 32.25806},
#     {'period': '2024-03-20', 'ratio': 19.35483},
#     {'period': '2024-03-21', 'ratio': 80.64516},
#     {'period': '2024-03-22', 'ratio': 38.70967},
#     {'period': '2024-03-23', 'ratio': 16.12903},
#     {'period': '2024-03-24', 'ratio': 19.35483},
#     {'period': '2024-03-25', 'ratio': 25.80645},
#     {'period': '2024-03-26', 'ratio': 35.48387},
#     {'period': '2024-03-27', 'ratio': 35.48387},
#     {'period': '2024-03-28', 'ratio': 9.67741},
#     {'period': '2024-03-29', 'ratio': 12.90322},
#     {'period': '2024-03-30', 'ratio': 9.67741},
#     {'period': '2024-03-31', 'ratio': 29.03225},
#     {'period': '2024-04-01', 'ratio': 25.80645},
#     {'period': '2024-04-02', 'ratio': 16.12903},
#     {'period': '2024-04-03', 'ratio': 12.90322},
#     {'period': '2024-04-04', 'ratio': 35.48387},
#     {'period': '2024-04-05', 'ratio': 22.58064},
#     {'period': '2024-04-06', 'ratio': 12.90322},
#     {'period': '2024-04-07', 'ratio': 9.67741},
#     {'period': '2024-04-08', 'ratio': 12.90322},
#     {'period': '2024-04-09', 'ratio': 12.90322},
#     {'period': '2024-04-10', 'ratio': 25.80645},
#     {'period': '2024-04-11', 'ratio': 19.35483},
#     {'period': '2024-04-12', 'ratio': 22.58064},
#     {'period': '2024-04-13', 'ratio': 12.90322},
#     {'period': '2024-04-14', 'ratio': 9.67741},
#     {'period': '2024-04-15', 'ratio': 12.90322},
#     {'period': '2024-04-16', 'ratio': 19.35483},
#     {'period': '2024-04-17', 'ratio': 9.67741},
#     {'period': '2024-04-18', 'ratio': 19.35483},
#     {'period': '2024-04-19', 'ratio': 6.45161},
#     {'period': '2024-04-20', 'ratio': 19.35483},
#     {'period': '2024-04-21', 'ratio': 16.12903},
#     {'period': '2024-04-22', 'ratio': 6.45161},
#     {'period': '2024-04-23', 'ratio': 12.90322},
#     {'period': '2024-04-24', 'ratio': 12.90322},
#     {'period': '2024-04-25', 'ratio': 9.67741},
#     {'period': '2024-04-26', 'ratio': 9.67741},
#     {'period': '2024-04-27', 'ratio': 19.35483},
#     {'period': '2024-04-28', 'ratio': 9.67741},
#     {'period': '2024-04-30', 'ratio': 9.67741},
#     {'period': '2024-05-01', 'ratio': 9.67741},
#     {'period': '2024-05-02', 'ratio': 6.45161},
#     {'period': '2024-05-03', 'ratio': 6.45161},
#     {'period': '2024-05-04', 'ratio': 16.12903},
#     {'period': '2024-05-05', 'ratio': 16.12903},
#     {'period': '2024-05-06', 'ratio': 12.90322},
#     {'period': '2024-05-07', 'ratio': 29.03225},
#     {'period': '2024-05-08', 'ratio': 19.35483},
#     {'period': '2024-05-09', 'ratio': 22.58064},
#     {'period': '2024-05-10', 'ratio': 9.67741},
#     {'period': '2024-05-11', 'ratio': 12.90322},
#     {'period': '2024-05-12', 'ratio': 12.90322},
#     {'period': '2024-05-13', 'ratio': 19.35483},
#     {'period': '2024-05-14', 'ratio': 32.25806},
#     {'period': '2024-05-15', 'ratio': 16.12903},
#     {'period': '2024-05-16', 'ratio': 19.35483},
#     {'period': '2024-05-17', 'ratio': 25.80645},
#     {'period': '2024-05-18', 'ratio': 9.67741},
#     {'period': '2024-05-19', 'ratio': 25.80645},
#     {'period': '2024-05-20', 'ratio': 6.45161},
#     {'period': '2024-05-21', 'ratio': 25.80645},
#     {'period': '2024-05-22', 'ratio': 29.03225},
#     {'period': '2024-05-23', 'ratio': 93.54838},
#     {'period': '2024-05-24', 'ratio': 100},
#     {'period': '2024-05-25', 'ratio': 16.12903},
#     {'period': '2024-05-26', 'ratio': 45.16129},
#     {'period': '2024-05-27', 'ratio': 29.03225},
#     {'period': '2024-05-28', 'ratio': 45.16129}]}]}

# %%
data = {
    "startDate": "2017-01-01",
    "endDate": "2017-04-30",
    "timeUnit": "month",
    "keywordGroups": [
        {
            "groupName": "엔비디아",
            "keywords": ["엔비디아", "NVIDIA", "GeForce"]
        }
    ],
    "device": "pc",
    "ages": ["1", "2"],
    "gender": "f"
}
